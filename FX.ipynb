# %% [markdown]
# Historical Exchange Rates
# ===
#
# *Data: **&copy; 1996 - 2019 OANDA Corporation**, [http://oanda.com](http://www.oanda.com/currency/historical-rates).*
#
# Downloaded 31 March 2016 onwards.
#
# Monthly values, from September 2007 to today, average between buy and sell.
#
# There surely would be a smart way to scrape it straight from the website, but for now, it is added manually.

# %%
import numpy as np
import datetime
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

# %%
# Use ggplot style, get color_cycle, set font-size
plt.style.use('ggplot')
rcParams['font.size'] = 10.0
rcParams['font.sans-serif'] =  'Ubuntu'

# Adjust dpi, so figure on screen and savefig looks the same
rcParams['figure.dpi'] = 300
rcParams['savefig.dpi'] = 300

# %% [markdown]
# ## Raw Data

# %%
#        YYYY.MM  MXN/CHF MXN/GBP MXN/USD MXN/EUR MXN/BRL    
data = np.array([
        [2019.11, 0.051493, 0.040252, 0.051850, 0.046907, 0.215285,],
        [2019.10, 0.051434, 0.040935, 0.051784, 0.046836, 0.211506,],
        [2019.09, 0.050576, 0.041336, 0.051065, 0.046378, 0.210387,],
        [2019.08, 0.049776, 0.041841, 0.050846, 0.045708, 0.204067,],
        [2019.07, 0.052208, 0.040103, 0.052147, 0.045943, 0.193870,],  # 2019.07 missing, copied Feb '19'
        [2019.06, 0.052208, 0.040103, 0.052147, 0.045943, 0.193870,],  # 2019.06 missing, copied Feb '19'
        [2019.05, 0.052208, 0.040103, 0.052147, 0.045943, 0.193870,],  # 2019.05 missing, copied Feb '19'
        [2019.04, 0.052208, 0.040103, 0.052147, 0.045943, 0.193870,],  # 2019.04 missing, copied Feb '19'
        [2019.03, 0.052208, 0.040103, 0.052147, 0.045943, 0.193870,],  # 2019.04 missing, copied Feb '19'
        [2019.02, 0.052208, 0.040103, 0.052147, 0.045943, 0.193870,],
        [2019.01, 0.051552, 0.040423, 0.052119, 0.045643, 0.195161,],
        [2018.12, 0.049378, 0.039262, 0.049760, 0.043740, 0.193515,],
        [2018.11, 0.049504, 0.038334, 0.049448, 0.043504, 0.186610,],
        [2018.10, 0.051914, 0.040120, 0.052245, 0.045464, 0.196726,],
        [2018.09, 0.050960, 0.040358, 0.052625, 0.045172, 0.215744,],
        [2018.08, 0.052518, 0.041247, 0.053081, 0.046006, 0.207858,],
        [2018.07, 0.052288, 0.039908, 0.052581, 0.044982, 0.200938,],
        [2018.06, 0.048836, 0.037112, 0.049336, 0.042256, 0.186118,],
        [2018.05, 0.051064, 0.038020, 0.051212, 0.043310, 0.185754,],
        [2018.04, 0.052724, 0.038724, 0.054458, 0.044364, 0.185354,],
        [2018.03, 0.050934, 0.038490, 0.053746, 0.043587, 0.176194,],
        [2018.02, 0.050142, 0.038396, 0.053673, 0.043452, 0.174251,],
        [2018.01, 0.050796, 0.038274, 0.052836, 0.043326, 0.169640,],
        [2017.12, 0.051436, 0.038874, 0.052128, 0.044028, 0.171843,],
        [2017.11, 0.052368, 0.039956, 0.052814, 0.044982, 0.172356,],
        [2017.10, 0.052204, 0.040278, 0.053164, 0.045233, 0.169464,],
        [2017.09, 0.053982, 0.042164, 0.056112, 0.047084, 0.175682,],
        [2017.08, 0.054226, 0.043362, 0.056193, 0.047557, 0.177212,],
        [2017.07, 0.053858, 0.043128, 0.056092, 0.048666, 0.179824,],
        [2010.06, 0.088629, 0.053322, 0.078615, 0.064370, 0.141970,],
        [2010.05, 0.088619, 0.053513, 0.078537, 0.062393, 0.142262,],
        [2010.04, 0.087206, 0.053298, 0.081704, 0.060809, 0.143754,],
        [2010.03, 0.084805, 0.052839, 0.079548, 0.058601, 0.142182,],
        [2010.02, 0.082923, 0.049572, 0.077311, 0.056544, 0.142499,],
        [2010.01, 0.080522, 0.048193, 0.077822, 0.054554, 0.138500,],
        [2009.12, 0.080199, 0.047998, 0.077865, 0.053405, 0.136534,],
        [2009.11, 0.077246, 0.045966, 0.076253, 0.051151, 0.131911,],
        [2009.10, 0.077184, 0.046683, 0.075508, 0.050976, 0.131239,],
        [2009.09, 0.077592, 0.045711, 0.074600, 0.051239, 0.135880,],
        [2009.08, 0.082105, 0.046472, 0.076858, 0.053898, 0.141901,],
        [2009.07, 0.080787, 0.045745, 0.074831, 0.053169, 0.144868,],
        [2009.06, 0.081081, 0.045836, 0.075001, 0.053527, 0.146768,],
        [2009.05, 0.083605, 0.048975, 0.075562, 0.055319, 0.156533,],
        [2009.04, 0.085758, 0.050762, 0.074686, 0.056563, 0.164672,],
        [2009.03, 0.078853, 0.048067, 0.068277, 0.052297, 0.157828,],
        [2009.02, 0.079792, 0.047517, 0.068588, 0.053542, 0.158915,],
        [2009.01, 0.080968, 0.049803, 0.072139, 0.054188, 0.167100,],
        [2008.12, 0.084948, 0.050145, 0.074489, 0.055209, 0.179234,],
        [2008.11, 0.090787, 0.049714, 0.076228, 0.059983, 0.172581,],
        [2008.10, 0.090739, 0.046901, 0.079503, 0.059680, 0.172291,],
        [2008.09, 0.104408, 0.052246, 0.094109, 0.065445, 0.168657,],
        [2008.08, 0.107134, 0.052360, 0.098875, 0.066082, 0.159279,],
        [2008.07, 0.100468, 0.049201, 0.097870, 0.062040, 0.155865,],
        [2008.06, 0.100288, 0.049214, 0.096845, 0.062165, 0.156763,],
        [2008.05, 0.099939, 0.048712, 0.095775, 0.061550, 0.158831,],
        [2008.04, 0.096400, 0.047978, 0.095102, 0.060365, 0.160477,],
        [2008.03, 0.094306, 0.046543, 0.093114, 0.060062, 0.159286,],
        [2008.02, 0.101326, 0.047305, 0.092847, 0.063019, 0.161057,],
        [2008.01, 0.101025, 0.046533, 0.091626, 0.062306, 0.162556,],
        [2007.12, 0.105054, 0.045690, 0.092151, 0.063302, 0.164431,],
        [2007.11, 0.103327, 0.044370, 0.091952, 0.062658, 0.162413,],
        [2007.10, 0.108502, 0.045209, 0.092414, 0.064931, 0.166248,],
        [2007.09, 0.107436, 0.044868, 0.090625, 0.065179, 0.172522,],
        ])

# %% [markdown]
# ## Labels etc

# %%
# Nr of months and Januarys, months as number-array, decreasing
nrm = np.size(data[:,0])
nrjans = int((nrm-4)/12+1)
months = np.arange(nrm, 0, -1)-1

# Label: empty string except for Januarys
mts, yrs = np.modf(data[:,0])
janlab = []
for i in months[4::12]:
    janlab += [datetime.date(int(yrs[i]), int(round(100*mts[i])), 1).strftime('%b \'%y')]
label = nrm*['']
label[4::12] = janlab[:nrjans]
label = label[-1::-1] # (reverse, like months and data)

# Labelticks
labeltic = np.array(label)
labeltic[labeltic != ''] = months[labeltic != '']
labeltic[labeltic == ''] = '0'
labeltic = labeltic.astype(float)

# Get start and end month name and year for plot titles
smtsyr = datetime.date(int(yrs[-1]), int(round(100*mts[-1])), 1).strftime('%b \'%y')
emteyr = datetime.date(int(yrs[0]), int(round(100*mts[0])), 1).strftime('%b \'%y')

# %% [markdown]
# ## Plots

# %%
fig1, ax = plt.subplots()

# Plot the data
plt.plot(months, data[:,1]/data[-1,1]*100, label='CHF')
plt.plot(months, data[:,2]/data[-1,2]*100, label='GBP')
plt.plot(months, data[:,3]/data[-1,3]*100, label='USD')
plt.plot(months, data[:,4]/data[-1,4]*100, label='EUR')
plt.plot(months, data[:,5]/data[-1,5]*100, label='BRL')

# Title, labels, legend, axis limits
plt.title(('Value of the Mexican Peso ('+smtsyr+' - '+emteyr+')'))
plt.ylabel('Percent %')
plt.legend(loc=3, ncol=2)
ax.axis([0, np.size(months)-1, 80*np.min(data[:,1:]/data[-1,1:]),  105*np.max(data[:,1:]/data[-1,1:])])
ax.set_xticks(labeltic)
ax.set_xticklabels(label)

# Save and show
plt.savefig('plots/MXNper.png', bbox_inches='tight')
plt.show()

# %%
fig1, ax = plt.subplots()

# Plot the data
plt.plot(months, data[:,1], label='CHF')
plt.plot(months, data[:,2], label='GBP')
plt.plot(months, data[:,3], label='USD')
plt.plot(months, data[:,4], label='EUR')
plt.plot(months, data[:,5], label='BRL')

# Title, labels, legend, axis limits
plt.title(('Exchange rate of the Mexican Peso ('+smtsyr+' - '+emteyr+')'))
plt.ylabel('Rate')
plt.legend(loc='best', ncol=2)
ax.axis([0, np.size(months)-1, 0,  1.05*np.max(data[:,1:])])
ax.set_xticks(labeltic)
ax.set_xticklabels(label)

# Save and show
plt.savefig('plots/MXNexr.png', bbox_inches='tight')
plt.show()

# %%
fig2, ax1 = plt.subplots()

# axis limits
axis = [0, np.size(months)-1, .9*np.min(data[:,1]),  1.05*np.max(data[:,1])]

# Plot data and set axis limits
ax1.plot(months, data[:,1], 'k')
ax1.axis(axis)

# Set label blue (1 MXN - x CHF)
for tl in ax1.get_yticklabels():
    tl.set_color('b')
ax1.set_ylabel('1 MXN = x CHF', color='b')

# Second plot for second label, without grid, same limits
ax2 = ax1.twinx()
ax2.grid('off')
ax2.axis(axis)

# Set label red (1 CHF - x MXN)
ax2.set_ylabel('1 CHF = x MXN', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# Get tick labels, and invert them
# NOTE: inverting them makes this scale non-linear!
labels = np.round(1/np.array(ax2.get_yticks().tolist()),1)
ax2.set_yticklabels(labels)

# Title and x-axis ticks
plt.title(('MXN/CHF exchange rates ('+smtsyr+' - '+emteyr+')'))
ax2.set_xticks(labeltic)
ax2.set_xticklabels(label)    

# Save and show
plt.savefig('plots/MXNexr.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Same as above, with a try to implement tooltips via mpld3.

# %%
import mpld3

fig3 = plt.figure(figsize=(3,2))

plt.plot(months, data[:,1], 'b')
points = plt.scatter(months, data[:,1], c='none', s=30)
plt.ylabel('1 MXN = x CHF')
plt.axis([0, np.size(months)-1, .9*np.min(data[:,1]),  1.05*np.max(data[:,1])])

labels = ['{0}'.format(i) for i in data[:,1]]
tooltip = mpld3.plugins.PointLabelTooltip(points, labels=labels)
mpld3.plugins.connect(fig3, tooltip)

#mpld3.fig_to_html(fig3)
mpld3.save_html(fig3, '/home/dtr/Desktop/test.html')

mpld3.display()
